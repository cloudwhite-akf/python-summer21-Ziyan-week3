# %%
a = "they came ..."
b = "by Martin Niemöller "
c = "And I did not speak out"
d = "Because I was not a"

li = ['Communists','Socialists,', 'trade unionists', 'Jews']

terms = ['And there was ']

print (f'First {a}')
print('\n')
print(b.upper())
print('\n')

print('First they came the') 
print(li[0])
print(c)
print(d)
print(li[0])
print('\n')

print('Then they came for the')
print(li[1])
print(c)
print(d)
print(li[1])
print('\n')

print('Then they came for the')
print(li[2])
print(c)
print(d)
print(li[2])
print('\n')

print('Then they came for the')
print(li[3])
print(c)
print(d)
print(li[3])
print('\n')

print('Then they came for me,')
for a in terms:
    print(a + 'no one left')
print("To speak out for me.")
print('\n')
# Out:
# First they came ...
#
#
# BY MARTIN NIEMÖLLER
#
#
# First they came the
# Communists
# And I did not speak out
# Because I was not a
# Communists
#
#
# Then they came for the
# Socialists,
# And I did not speak out
# Because I was not a
# Socialists,
#
#
# Then they came for the
# trade unionists
# And I did not speak out
# Because I was not a
# trade unionists
#
#
# Then they came for the
# Jews
# And I did not speak out
# Because I was not a
# Jews
#
#
# Then they came for me,
# And there was no one left
# To speak out for me.
